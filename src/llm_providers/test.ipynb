# %%
from openai import OpenAI
from dotenv import load_dotenv
from config.config import Config
import os
from 
settings = Config()

settings.base_url
# Out:
# 'https://api.groq.com/openai/v1'

# %%
client = OpenAI(api_key=settings.groq_api_key,base_url=settings.base_url)

response = client.responses.create(model=settings.model_name,input="my name is abram how are you ?")



print(response.output_text)
# Out:
# Hi Abram! I'm doing great—thanks for asking. How about you? How's your day going?
