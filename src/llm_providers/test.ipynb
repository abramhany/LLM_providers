# %%
from providers.openai_gateway import Openai_gateway
from dotenv import load_dotenv
from config.config import Config
import os
from schema.chat import Chat , Message
from enums.roles import Role
settings = Config()

settings.base_url
# Out:
# 'https://api.groq.com/openai/v1'

# %%
message_list =[ Message(role=Role.SYSTEM,content='you are an ai assesstant'),Message(role=Role.USER,content='How are you today')]

# %%
messages = Chat(messages=message_list)

# %%
client = Openai_gateway(config=settings)

response = client.chat(messages)



print(response.output_text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 client = OpenAI()
#       2
#       3 response = client.responses.create(model=settings.model_name,input="my name is abram how are you ?")
#       4
#
# NameError: name 'OpenAI' is not defined
