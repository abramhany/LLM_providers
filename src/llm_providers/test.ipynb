# %%
from providers.openai_gateway import Openai_gateway 
from providers.gateway import Gateway
from dotenv import load_dotenv
from config.config import Config
import os
from schema.chat import Chat , Message
from enums.roles import Role
settings = Config()

settings.base_url
# Out:
# 'https://api.groq.com/openai/v1'

# %%
message_list =[ Message(role=Role.SYSTEM,content='you are an ai assesstant'),Message(role=Role.USER,content='How are you today')]

# %%
gateway = Gateway(Config=settings,llm_provider=Openai_gateway(config=settings))

# %%
chat = Chat(messages=message_list)
response = gateway.generation(chat_input=chat)



print(response)
# Out:
# 0.40588939675084157
# 1.9759338997770108
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# File D:\Programing\Depi\LLM_providers\src\providers\openai_gateway.py:41, in Openai_gateway.chat(self, chat_input)
#      39 try:
# ---> 41     response = self.client.chat.completions.create(**param)
#      42     content = response.choices[0].message.content
#
# File d:\Programing\Depi\LLM_providers\.venv\Lib\site-packages\openai\_utils\_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# File d:\Programing\Depi\LLM_providers\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py:1308, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, moderation, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_options, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1307 validate_response_format(response_format)
# -> 1308 return self._post(
#    1309     "/chat/completions",
#    1310     body=maybe_transform(
#    1311         {
#    1312             "messages": messages,
#    1313             "model": model,
#    1314             "audio": audio,
#    1315             "frequency_penalty": frequency_penalty,
#    1316             "function_call": function_call,
#    1317             "functions": functions,
#    1318             "logit_bias": logit_bias,
#    1319             "logprobs": logprobs,
#    1320             "max_completion_tokens": max_completion_tokens,
#    1321             "max_tokens": max_tokens,
#    1322             "metadata": metadata,
#    1323             "modalities": modalities,
#    1324             "moderation": moderation,
#    1325             "n": n,
#    1326             "parallel_tool_calls": parallel_tool_calls,
#    1327             "prediction": prediction,
#    1328             "presence_penalty": presence_penalty,
#    1329             "prompt_cache_key": prompt_cache_key,
#    1330             "prompt_cache_options": prompt_cache_options,
#    1331             "prompt_cache_retention": prompt_cache_retention,
#    1332             "reasoning_effort": reasoning_effort,
#    1333             "response_format": response_format,
#    1334             "safety_identifier": safety_identifier,
#    1335             "seed": seed,
#    1336             "service_tier": service_tier,
#    1337             "stop": stop,
#    1338             "store": store,
#    1339             "stream": stream,
#    1340             "stream_options": stream_options,
#    1341             "temperature": temperature,
#    1342             "tool_choice": tool_choice,
#    1343             "tools": tools,
#    1344             "top_logprobs": top_logprobs,
#    1345             "top_p": top_p,
#    1346             "user": user,
#    1347             "verbosity": verbosity,
#    1348             "web_search_options": web_search_options,
#    1349         },
#    1350         completion_create_params.CompletionCreateParamsStreaming
#    1351         if stream
#    1352         else completion_create_params.CompletionCreateParamsNonStreaming,
#    1353     ),
#    1354     options=make_request_options(
#    1355         extra_headers=extra_headers,
#    1356         extra_query=extra_query,
#    1357         extra_body=extra_body,
#    1358         timeout=timeout,
#    1359         security={"bearer_auth": True},
#    1360     ),
#    1361     cast_to=ChatCompletion,
#    1362     stream=stream or False,
#    1363     stream_cls=Stream[ChatCompletionChunk],
#    1364 )
#
# File d:\Programing\Depi\LLM_providers\.venv\Lib\site-packages\openai\_base_client.py:1368, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1365 opts = FinalRequestOptions.construct(
#    1366     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1367 )
# -> 1368 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File d:\Programing\Depi\LLM_providers\.venv\Lib\site-packages\openai\_base_client.py:1141, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1140     log.debug("Re-raising status error")
# -> 1141     raise self._make_status_error_from_response(err.response) from None
#    1143 break
#
# AuthenticationError: Error code: 401 - {'error': {'message': 'Invalid API Key', 'type': 'invalid_request_error', 'code': 'invalid_api_key'}}
#
# The above exception was the direct cause of the following exception:
#
# Authentication_Error                      Traceback (most recent call last)
# Cell In[4], line 2
#       1 chat = Chat(messages=message_list)
# ----> 2 response = gateway.chat(chat_input=chat)
#       3
#       4
#       5
#
# File D:\Programing\Depi\LLM_providers\src\providers\gateway.py:27, in Gateway.chat(self, chat_input)
#      25 for attempts in range(1,self.max_attempts+1):
#      26     try:
# ---> 27         return self.llm_provider.chat(chat_input=chat_input)
#      28     except(Connection_Error,RateLimit_Error,Provider_Error,Authentication_Error) as e:
#      29        if attempts == self.max_attempts:
#
# File D:\Programing\Depi\LLM_providers\src\providers\openai_gateway.py:53, in Openai_gateway.chat(self, chat_input)
#      51     raise Connection_Error(LLMError.CONNECTION_ERROR) from e
#      52 except AuthenticationError as e :
# ---> 53     raise Authentication_Error(LLMError.AUTENTICATION_ERROR) from e
#      54 except RateLimitError as e:
#      55     raise RateLimit_Error(LLMError.RATE_LIMIT_EXCEEDED) from e
#
# Authentication_Error: LLMError.AUTENTICATION_ERROR
